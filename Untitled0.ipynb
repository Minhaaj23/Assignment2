# %% [markdown]
# <a href="https://colab.research.google.com/github/Minhaaj23/Assignment2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-plot
# Out:
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7

# %%
pip install -U voyageai
# Out:
# Collecting voyageai
#   Downloading voyageai-0.2.3-py3-none-any.whl (19 kB)
# Requirement already satisfied: aiohttp<4.0,>=3.5 in /usr/local/lib/python3.10/dist-packages (from voyageai) (3.9.5)
# Collecting aiolimiter<2.0.0,>=1.1.0 (from voyageai)
#   Downloading aiolimiter-1.1.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from voyageai) (1.25.2)
# Requirement already satisfied: requests<3.0,>=2.20 in /usr/local/lib/python3.10/dist-packages (from voyageai) (2.31.0)
# Requirement already satisfied: tenacity>=8.0.1 in /usr/local/lib/python3.10/dist-packages (from voyageai) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.5->voyageai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.5->voyageai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.5->voyageai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.5->voyageai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.5->voyageai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.5->voyageai) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20->voyageai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20->voyageai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20->voyageai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20->voyageai) (2024.2.2)
# Installing collected packages: aiolimiter, voyageai
# Successfully installed aiolimiter-1.1.0 voyageai-0.2.3

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
import voyageai
import os
import pandas as pd
import numpy as np
from dotenv import load_dotenv, find_dotenv
from pathlib import Path
load_dotenv(Path(".env"))

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

VOYAGE_API_KEY = 'pa-4j2cXfxLlWzuFGE-o25WgmgCP-A7ohVyO56NHgBU83U'

# %%
vo = voyageai.Client(api_key=VOYAGE_API_KEY)
# This will automatically use the environment variable VOYAGE_API_KEY.
# Alternatively, you can use vo = voyageai.Client(api_key="<your secret key>")

df = pd.read_excel("Dataset Problem - 1.xlsx", sheet_name = "Dataset_problem_1")

# Dropping Null Rows
df = df.dropna()


# Get the embeddings for the text data
df_text_list = df['text'].tolist()


batch_size = 128
print("Total documents:", len(df_text_list))
embeddings = []

for i in range(0, len(df_text_list), batch_size):
    batch = df_text_list[i:i + batch_size]

    print(f"Embedding documents {i} to {i + len(batch) - 1}")
    # print("Total tokens:", vo.count_tokens(batch))

    batch_embeddings = vo.embed(
        batch, model="voyage-large-2"
    ).embeddings
    embeddings += batch_embeddings

    print("Embeddings preview:", embeddings[0][:5])
# Out:
# Total documents: 134329
# Embedding documents 0 to 127
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128 to 255
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 256 to 383
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 384 to 511
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 512 to 639
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 640 to 767
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 768 to 895
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 896 to 1023
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 1024 to 1151
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 1152 to 1279
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 1280 to 1407
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 1408 to 1535
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 1536 to 1663
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 1664 to 1791
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 1792 to 1919
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 1920 to 2047
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 2048 to 2175
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 2176 to 2303
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 2304 to 2431
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 2432 to 2559
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 2560 to 2687
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 2688 to 2815
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 2816 to 2943
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 2944 to 3071
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 3072 to 3199
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 3200 to 3327
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 3328 to 3455
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 3456 to 3583
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 3584 to 3711
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 3712 to 3839
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 3840 to 3967
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 3968 to 4095
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 4096 to 4223
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 4224 to 4351
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 4352 to 4479
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 4480 to 4607
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 4608 to 4735
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 4736 to 4863
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 4864 to 4991
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 4992 to 5119
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 5120 to 5247
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 5248 to 5375
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128000 to 128127
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128128 to 128255
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128256 to 128383
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128384 to 128511
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128512 to 128639
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128640 to 128767
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128768 to 128895
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 128896 to 129023
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 129024 to 129151
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 129152 to 129279
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 129280 to 129407
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 129408 to 129535
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 129536 to 129663
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 129664 to 129791
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 129792 to 129919
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 129920 to 130047
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 130048 to 130175
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 130176 to 130303
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 130304 to 130431
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 130432 to 130559
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 130560 to 130687
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 130688 to 130815
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 130816 to 130943
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 130944 to 131071
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 131072 to 131199
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 131200 to 131327
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 131328 to 131455
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 131456 to 131583
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 131584 to 131711
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 131712 to 131839
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 131840 to 131967
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 131968 to 132095
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 132096 to 132223
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 132224 to 132351
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 132352 to 132479
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 132480 to 132607
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 132608 to 132735
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 132736 to 132863
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 132864 to 132991
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 132992 to 133119
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 133120 to 133247
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 133248 to 133375
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 133376 to 133503
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 133504 to 133631
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 133632 to 133759
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 133760 to 133887
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 133888 to 134015
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 134016 to 134143
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 134144 to 134271
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]
# Embedding documents 134272 to 134328
# Embeddings preview: [0.0008909407188184559, 0.004348745569586754, 0.019346971064805984, 0.004406947176903486, 0.046802982687950134]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve

import scikitplot as skplt
import matplotlib.pyplot as plt
import seaborn as sns

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(embeddings, df['sentiment'], test_size=0.2, random_state=42)

# Train a binary classifier
classifier = LogisticRegression()
classifier.fit(X_train, y_train)

# Make predictions
y_pred = classifier.predict(X_test)
y_proba = classifier.predict_proba(X_test)[:, 1]

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.7784560410928311
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78     13130
#            1       0.79      0.77      0.78     13736
#
#     accuracy                           0.78     26866
#    macro avg       0.78      0.78      0.78     26866
# weighted avg       0.78      0.78      0.78     26866

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(embeddings, df['sentiment'], test_size=0.2, random_state=42)

# Train a KMeans classifier
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_train)

# Predict clusters for the test set
y_train_pred = kmeans.predict(X_train)
y_test_pred = kmeans.predict(X_test)

# Determine which cluster corresponds to which sentiment label
# This assumes that the cluster with more positive sentiment is labeled as 1 and the other as 0
from scipy.stats import mode

def map_cluster_to_label(y_true, y_pred):
    labels = np.zeros_like(y_pred)
    for i in range(2):
        mask = (y_pred == i)
        labels[mask] = mode(y_true[mask])[0]
    return labels

# Map the predicted clusters to original sentiment labels
y_train_pred_mapped = map_cluster_to_label(y_train, y_train_pred)
y_test_pred_mapped = map_cluster_to_label(y_test, y_test_pred)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_test_pred_mapped)
report = classification_report(y_test, y_test_pred_mapped)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_test_pred_mapped)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy: 0.5275441077942381
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.24      0.33     13130
#            1       0.52      0.80      0.64     13736
#
#     accuracy                           0.53     26866
#    macro avg       0.53      0.52      0.48     26866
# weighted avg       0.53      0.53      0.49     26866
